# %%
#Importing the libarries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("FCRegister1final.csv",  low_memory=False) #reading the excel file

# %%
df.describe() #display with description of statistics
# Out:
#           APINumber       Latitude      Longitude           TVD  \
# count  2.985000e+05  298500.000000  298500.000000  2.985000e+05
# mean   3.585229e+13      35.527482    -100.602600  8.628478e+03
# std    1.231985e+13       5.776017       7.023193  1.775053e+04
# min    4.226933e+09      26.252660    -150.298034  0.000000e+00
# 25%    3.401922e+13      31.543600    -103.410877  6.551000e+03
# 50%    4.213542e+13      33.030920    -101.633880  8.466000e+03
# 75%    4.236538e+13      40.063680     -98.186139  1.084600e+04
# max    5.073320e+13      70.496116     -75.599947  2.253510e+06
#
#        TotalBaseWaterVolume  TotalBaseNonWaterVolume      FFVersion  \
# count          2.985000e+05             2.984710e+05  298500.000000
# mean           2.807170e+06             5.489493e+05       2.003866
# std            2.933850e+06             5.842790e+06       0.073613
# min            0.000000e+00            -1.082290e+05       1.000000
# ...

# %%
df
# Out:
#                                 DisclosureId JobStartDate JobStartTime  \
# 0       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 1       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 2       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 3       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 4       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# ...                                      ...          ...          ...
# 298495  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298496  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298497  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298498  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298499  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
#
#        JobEndDate   JobEndTime       APINumber StateName CountyName  \
# ...

# %%
df.dtypes #datatypes
# Out:
# DisclosureId                object
# JobStartDate                object
# JobStartTime                object
# JobEndDate                  object
# JobEndTime                  object
# APINumber                    int64
# StateName                   object
# CountyName                  object
# OperatorName                object
# WellName                    object
# Latitude                   float64
# Longitude                  float64
# Projection                  object
# TVD                          int64
# TotalBaseWaterVolume         int64
# TotalBaseNonWaterVolume    float64
# FFVersion                    int64
# FederalWell                   bool
# IndianWell                    bool
# PurposeId                   object
# TradeName                   object
# Supplier                    object
# Purpose                     object
# IngredientsId               object
# CASNumber                   object
# IngredientName              object
# IngredientCommonName        object
# ...

# %%
df.isnull().sum #checking for null values
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         DisclosureId  JobStartDate  JobStartTime  JobEndDate  JobEndTime  \
# 0              False         False         False       False       False
# 1              False         False         False       False       False
# 2              False         False         False       False       False
# 3              False         False         False       False       False
# 4              False         False         False       False       False
# ...              ...           ...           ...         ...         ...
# 298495         False         False         False       False       False
# 298496         False         False         False       False       False
# 298497         False         False         False       False       False
# 298498         False         False         False       False       False
# 298499         False         False         False       False       False
#
# ...

# %%
columns_to_clean = ['TotalBaseWaterVolume',
    'TotalBaseNonWaterVolume','PurposeId', 'TradeName', 'Supplier', 'Purpose', 'IngredientsId',
    'IngredientCommonName', 'PercentHighAdditive','IngredientComment', 'IngredientMSDS', 'MassIngredient',
    'ClaimantCompany'
                    
]

# Remove null values from  columns
df_cleaned = df.dropna(subset=columns_to_clean)  # cleaning columns with null values

# Display the cleaned Data
print(df_cleaned)
# Out:
#                                 DisclosureId JobStartDate JobStartTime  \
# 0       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 1       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 2       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 3       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 4       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# ...                                      ...          ...          ...
# 298495  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298496  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298497  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298498  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298499  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
#
#        JobEndDate   JobEndTime       APINumber StateName CountyName  \
# ...

# %%
data = df_cleaned

df = pd.DataFrame(data)
#show clenaed data
#print(df('MassIngredient'))

# %%
df
# Out:
#                                 DisclosureId JobStartDate JobStartTime  \
# 0       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 1       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 2       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 3       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 4       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# ...                                      ...          ...          ...
# 298495  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298496  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298497  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298498  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298499  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
#
#        JobEndDate   JobEndTime       APINumber StateName CountyName  \
# ...

# %%
print(df_cleaned)
# Out:
#                                 DisclosureId JobStartDate JobStartTime  \
# 0       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 1       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 2       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 3       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 4       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# ...                                      ...          ...          ...
# 298495  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298496  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298497  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298498  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298499  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
#
#        JobEndDate   JobEndTime       APINumber StateName CountyName  \
# ...

# %%
df.shape #dispaly rows and columns number
# Out:
# (296708, 33)

# %%
any_nulls = df.isnull().values.any()

if any_nulls:
    print("There are null values in the DataFrame.")
else:
    print("There are no null values in the DataFrame.")

#null values
# Out:
# There are null values in the DataFrame.

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         DisclosureId  JobStartDate  JobStartTime  JobEndDate  JobEndTime  \
# 0              False         False         False       False       False
# 1              False         False         False       False       False
# 2              False         False         False       False       False
# 3              False         False         False       False       False
# 4              False         False         False       False       False
# ...              ...           ...           ...         ...         ...
# 298495         False         False         False       False       False
# 298496         False         False         False       False       False
# 298497         False         False         False       False       False
# 298498         False         False         False       False       False
# 298499         False         False         False       False       False
#
# ...

# %%
df_cleaned = df.dropna()

# %%
df_cleaned
# Out:
#                                 DisclosureId JobStartDate JobStartTime  \
# 0       e07e0ed2-75cd-4c0d-80bc-16211e67beda   2023-03-29  12:00:00 AM
# 1       e07e0ed2-75cd-4c0d-80bc-16211e67beda   2023-03-29  12:00:00 AM
# 2       e07e0ed2-75cd-4c0d-80bc-16211e67beda   2023-03-29  12:00:00 AM
# 3       e07e0ed2-75cd-4c0d-80bc-16211e67beda   2023-03-29  12:00:00 AM
# 4       e07e0ed2-75cd-4c0d-80bc-16211e67beda   2023-03-29  12:00:00 AM
# ...                                      ...          ...          ...
# 298495  356e2b4e-4425-4c12-b1db-d6b7021c54e8   2013-07-16  12:00:00 AM
# 298496  356e2b4e-4425-4c12-b1db-d6b7021c54e8   2013-07-16  12:00:00 AM
# 298497  356e2b4e-4425-4c12-b1db-d6b7021c54e8   2013-07-16  12:00:00 AM
# 298498  356e2b4e-4425-4c12-b1db-d6b7021c54e8   2013-07-16  12:00:00 AM
# 298499  356e2b4e-4425-4c12-b1db-d6b7021c54e8   2013-07-16  12:00:00 AM
#
#        JobEndDate   JobEndTime       APINumber StateName CountyName  \
# ...

# %%
df=df_cleaned

# %%
df['IngredientMSDS'].value_counts() #counting true false
# Out:
# True     212552
# False     84154
# Name: IngredientMSDS, dtype: int64

# %%
df['FederalWell'].value_counts()
# Out:
# False    278982
# True      17724
# Name: FederalWell, dtype: int64

# %%
df['IndianWell'].value_counts()
# Out:
# False    296673
# True         33
# Name: IndianWell, dtype: int64

# %%
#from sklearn.preprocessing import LabelEncoder extra
#le=LabelEncoder()
#df['IngredientMSDS']= le.fit_transform(df['IngredientMSDS'])
#df

# %%
df['IngredientMSDS'] = df['IngredientMSDS'].astype(int) #works convert into int
df['FederalWell'] = df['FederalWell'].astype(int)
df['IndianWell'] = df['IndianWell'].astype(int)

# Display the DataFrame with the encoded columns
print(df)
# Out:
# C:\Users\tasne\AppData\Local\Temp\ipykernel_10964\1100385177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IngredientMSDS'] = df['IngredientMSDS'].astype(int) #works
# C:\Users\tasne\AppData\Local\Temp\ipykernel_10964\1100385177.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FederalWell'] = df['FederalWell'].astype(int)
# C:\Users\tasne\AppData\Local\Temp\ipykernel_10964\1100385177.py:3: SettingWithCopyWarning:
# ...

# %%
df['FederalWell'].value_counts()
# Out:
# 0    278982
# 1     17724
# Name: FederalWell, dtype: int64

# %%
df['IndianWell'].value_counts()
# Out:
# 0    296673
# 1        33
# Name: IndianWell, dtype: int64

# %%
df['IngredientMSDS'].value_counts()
# Out:
# 1    212552
# 0     84154
# Name: IngredientMSDS, dtype: int64

# %%
#def formatapi(number):  extra
 #number=str(APINumber)
 #formatapi= '-'.join([number[:2], number[2:5], number[5:10], number[10:12], number[12:]])
 #return formatapi
#print(formatapi)

# %%
df
# Out:
#                                 DisclosureId JobStartDate JobStartTime  \
# 0       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 1       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 2       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 3       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 4       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# ...                                      ...          ...          ...
# 298495  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298496  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298497  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298498  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298499  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
#
#        JobEndDate   JobEndTime       APINumber StateName CountyName  \
# ...

# %%
# Drop the duplicate column
#df = df.loc[:, ~df.columns.duplicated()]

# %%
#df = df.iloc[:, :-1]

# %%
df
# Out:
#                                 DisclosureId JobStartDate JobStartTime  \
# 0       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 1       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 2       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 3       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 4       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# ...                                      ...          ...          ...
# 298495  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298496  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298497  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298498  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298499  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
#
#        JobEndDate   JobEndTime       APINumber StateName CountyName  \
# ...

# %%
# Out:
#                                 DisclosureId JobStartDate JobStartTime  \
# 0       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 1       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 2       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 3       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 4       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# ...                                      ...          ...          ...
# 298495  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298496  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298497  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298498  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298499  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
#
#        JobEndDate   JobEndTime       APINumber StateName CountyName  \
# ...

# %%
#df1=df.drop(df.columns[30], axis=1, inplace=True)

# %%
#df1

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                 DisclosureId JobStartDate JobStartTime  \
# 0       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 1       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 2       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 3       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# 4       e07e0ed2-75cd-4c0d-80bc-16211e67beda    3/29/2023  12:00:00 AM
# ...                                      ...          ...          ...
# 298495  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298496  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298497  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298498  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
# 298499  356e2b4e-4425-4c12-b1db-d6b7021c54e8    7/16/2013  12:00:00 AM
#
#        JobEndDate   JobEndTime       APINumber StateName CountyName  \
# ...

# %%
#pairplot for the datset
sns.pairplot(df)

# %%
df['JobStartDate'] = pd.to_datetime(df['JobStartDate'], format='%m/%d/%Y') #convert to string 
df['JobEndDate'] = pd.to_datetime(df['JobEndDate'], format='%m/%d/%Y')

# %%
df['Duration'] = (df['JobEndDate'] - df['JobStartDate']).dt.days

# %%
print(df['Duration'])

# %%
print(df['Duration'].head())

# %%
invalid_rows = df[df['JobStartDate'] > df['JobEndDate']]

# Drop the invalid rows from the DataFrame
df.drop(invalid_rows.index, inplace=True)

print(df)

# %%
df['Duration'] = (df['JobEndDate'] - df['JobStartDate']).dt.days

# %%
print(df['Duration'])

# %%
df.to_csv("C:/Users/tasne/Downloads/Chirality_project/newdf.csv")

# %%
wells_state = df['StateName'].value_counts()

# Show the count of wells by state
print(wells_state)

# state with the highest number of wells
state_high= wells_state.idxmax()
print(f"highest number of wells is {state_high} with {wells_state.max()} wells.")
# Out:
# Texas            155633
# North Dakota      24464
# Oklahoma          23513
# Colorado          23242
# Utah              15511
# Wyoming           11379
# Pennsylvania       9681
# New Mexico         8544
# Arkansas           5538
# California         4759
# Ohio               3858
# Louisiana          3192
# West Virginia      2993
# Kansas             1997
# Montana            1620
# Alaska              355
# Virginia            179
# Mississippi         144
# Michigan             92
# Nebraska             12
# Name: StateName, dtype: int64
# highest number of wells is Texas with 155633 wells.

# %%
wells_operator = df['OperatorName'].value_counts()

# Find the operator with the highest number of wells
operator1 = wells_operator.idxmax()
max_count = wells_operator.max()

print(f"The operator with the highest number of wells is '{operator1}' with {max_count} wells.")
# Out:
# The operator with the highest number of wells is 'Chesapeake Operating, Inc.' with 19215 wells.

# %%
max_mass = df['MassIngredient'].idxmax() #print higest mass from ingredient mass
name = df.loc[max_mass, 'IngredientName']
max_mass = df.loc[max_mass, 'MassIngredient']

print(f"The ingredient with the highest mass is '{name}' with a mass of {max_mass} pounds.")
# Out:
# The ingredient with the highest mass is 'Ammonium Persulfate' with a mass of 5841500000.0 pounds.

# %%
df['PercentHighAdditive'] = df['PercentHighAdditive'].str.rstrip('%').astype(float) #remove % sign
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df['PercentHighAdditive'] = df['PercentHighAdditive'].str.rstrip('%').astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...

# %%
correlation = df['TVD'].corr(df['TotalBaseWaterVolume'])

# %%
print(correlation)
# Out:
# 0.021601658690092132

# %%
mean= df.groupby('TVD')['TotalBaseWaterVolume'].mean() #calculate mean of tvd nad total base water

# %%
mean
# Out:
# TVD
# 0          2.311845e+06
# 1          5.159213e+06
# 21         2.101974e+06
# 565        1.705200e+04
# 600        1.337178e+04
#                ...
# 22125      2.267603e+06
# 24551      2.002000e+03
# 56980      4.109042e+06
# 131239     3.441109e+06
# 2253510    1.090500e+04
# Name: TotalBaseWaterVolume, Length: 6050, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame(data)

# Create a pair plot
sns.pairplot(df)
plt.show()
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
counts = df[['IndianWell', 'FederalWell']].apply(pd.value_counts).transpose()

# Plot the counts using a bar plot
counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Counts of Indian Wells and Federal Wells')
plt.xlabel('Well Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Well Type', loc='upper right')
plt.show()

# %%
# Histogram of TVD
plt.hist(df['TVD'], bins=20)
plt.title('Histogram of TVD')
plt.xlabel('TVD')
plt.ylabel('Frequency')
plt.show()

# %%
# Line graph of JobStartDate vs OperatorName (first 10 rows)
plt.plot(df['JobStartDate'].head(50), df['OperatorName'].head(50), label='OperatorName', marker='o', linestyle='-')
plt.title('Line Graph of JobStartDate vs OperatorName')
plt.xlabel('JobStartDate')
plt.ylabel('OperatorName')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
# Assuming your DataFrame is named df
numerical_columns = ['TotalBaseWaterVolume', 
                     'TotalBaseNonWaterVolume','MassIngredient']

# Compute descriptive statistics
statistics = df[numerical_columns].describe()

# Display the statistics
print(statistics)
# Out:
#        TotalBaseWaterVolume  TotalBaseNonWaterVolume  MassIngredient
# count          2.967080e+05             2.967080e+05    2.967080e+05
# mean           2.797967e+06             5.520666e+05    7.721606e+05
# std            2.922830e+06             5.859970e+06    3.771428e+07
# min            0.000000e+00            -1.082290e+05    0.000000e+00
# 25%            5.338480e+05             0.000000e+00    0.000000e+00
# 50%            1.927559e+06             0.000000e+00    3.000000e+00
# 75%            4.074254e+06             1.109700e+04    8.070000e+02
# max            5.379805e+07             1.848541e+08    5.841500e+09

# %%
correlation_matrix = df[['TVD', 'TotalBaseWaterVolume', 'TotalBaseNonWaterVolume']].corr()
print(correlation_matrix)
# Out:
#                               TVD  TotalBaseWaterVolume  \
# TVD                      1.000000              0.021601
# TotalBaseWaterVolume     0.021601              1.000000
# TotalBaseNonWaterVolume -0.003740             -0.036476
#
#                          TotalBaseNonWaterVolume
# TVD                                    -0.003740
# TotalBaseWaterVolume                   -0.036476
# TotalBaseNonWaterVolume                 1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt


correlation_matrix = df[['TVD', 'TotalBaseWaterVolume', 'TotalBaseNonWaterVolume']].corr()

##heatmap
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
df.TVD.mean()
# Out:
# 8626.156595036196

# %%
#Importing the necessaries Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df1= pd.read_csv("C:/Users/tasne/Downloads/Chirality_project/FracFocusCSV/WaterSource_1.csv")

# %%
df1
# Out:
#                             WaterSourceId  \
# 0    41eaf0d1-85f2-4c7a-9209-924f6fd66baf
# 1    e4691891-e699-4d74-a7e9-0d58d82c3a02
# 2    baf31ad4-1d57-486e-bd69-bce7a7df3e32
# 3    aab1c4d5-0cf5-44d9-82d2-83adf6119c11
# 4    4f66ea6c-2597-452f-89ee-2af7ac0db6e2
# ..                                    ...
# 293  f03d4903-a077-45f1-b765-c3b5ea5b9cc5
# 294  c3e18867-9e1e-406e-80f2-2a22ec9cb35d
# 295  12b515bf-4260-4486-b630-fa22be0f6e21
# 296  59ca9e5b-8490-48c5-b4e8-a02e6c252719
# 297  0928fbfc-8ef0-4a5e-80fe-27491240a8d2
#
#                              DisclosureId         APINumber     StateName  \
# 0    44e6a811-caa9-4ce6-973d-0169bc4953b7  51-235-10880-000      Colorado
# 1    42817453-975c-4fa6-aba1-025b4123c447  51-235-10880-000      Colorado
# 2    2acfafeb-8a0a-45f4-8530-036d93e40d0b  51-235-10880-000         Texas
# 3    e70acbb5-963c-4ea9-ab0a-03a80ecbfb7f  51-235-10880-000  North Dakota
# 4    e70acbb5-963c-4ea9-ab0a-03a80ecbfb7f  51-235-10880-000  North Dakota
# ...

# %%
print(df.dtypes)
# Out:
# WaterSourceId     object
# DisclosureId      object
# APINumber          int64
# StateName         object
# CountyName        object
# OperatorName      object
# WellName          object
# Description       object
# Percent          float64
# dtype: object

# %%
print(df.describe())
# Out:
#           APINumber     Percent
# count  2.980000e+02  298.000000
# mean   3.076382e+13   84.041913
# std    1.335044e+13   32.644810
# min    1.073219e+12    0.050000
# 25%    3.002551e+13   96.730000
# 50%    3.306105e+13  100.000000
# 75%    4.210934e+13  100.000000
# max    4.902728e+13  100.000000

# %%
missing_values = df.isnull()

# Display the DataFrame of missing values
print(missing_values)
# Out:
#      WaterSourceId  DisclosureId  APINumber  StateName  CountyName  \
# 0            False         False      False      False       False
# 1            False         False      False      False       False
# 2            False         False      False      False       False
# 3            False         False      False      False       False
# 4            False         False      False      False       False
# ..             ...           ...        ...        ...         ...
# 293          False         False      False      False       False
# 294          False         False      False      False       False
# 295          False         False      False      False       False
# 296          False         False      False      False       False
# 297          False         False      False      False       False
#
#      OperatorName  WellName  Description  Percent
# 0           False     False        False    False
# 1           False     False        False    False
# ...

# %%
any_null_values = df.isnull().any().any()

# %%
print("any null values??", any_null_values)
# Out:
# any null values?? False

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='WaterSourceId', y='Percent', data=df)
plt.title('Scatter Plot of Percent vs. WaterSourceId')
plt.xlabel('WaterSourceId')
plt.ylabel('Percent')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='StateName', data=df)
plt.title('Bar Plot of StateName vs. Count')
plt.xlabel('StateName')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Percent'], kde=True)
plt.title('Histogram of Percent')
plt.xlabel('Percent')
plt.ylabel('Frequency')
plt.show()
